# %% [markdown]
# # 📑 &nbsp; Deep Learning. Cultivar Recognition
#
# In this project, we'll classify images from the dataset
# <a href='https://www.kaggle.com/olgabelitskaya/tomato-cultivars'>Tomato Cultivars</a>.<br/>
# The content is about 700-800 images (160x160x3) with 15 tomato cultivars<br/>
# stored in the file of <i>Hierarchical Data Format (HDF5)</i>and it's in the building process.<br/>
# In the original dataset, photo files have the extension PNG and they are labeled by file prefixes.<br/>
# We'll preprocess the images, represent their examples, then train neural networks and other algorithms.<br/>
# We are going to apply:<br/>
# 1) <a href='https://scikit-learn.org/stable/'>scikit-learn: Machine Learning in Python</a><br/>
# 2) <a href='https://keras.io/'>Keras: a Python Deep Learning Library</a><br/>
# 3) <a href='https://pytorch.org/'>PyTorch: an Open Source Machine Learning Framework</a>.<br/>
# ## ✒️ &nbsp; Importing Libraries and Defining Helpful Functions

# %%
# !python3 -m pip install --upgrade pip \
--user --quiet --no-warn-script-location
# !python3 -m pip install neural_structured_learning \
--user --quiet --no-warn-script-location

# %%
spath='/root/.local/lib/python3.6/'
import sys; sys.path.append(spath)
import warnings; warnings.filterwarnings('ignore')
from IPython.display import display,HTML
import h5py,urllib,torch,tensorflow as tf
import pandas as pd,numpy as np,pylab as pl
from sklearn.ensemble import RandomForestClassifier as sRFC
from sklearn.metrics import accuracy_score,hamming_loss
from sklearn.metrics import classification_report
import tensorflow_hub as th,neural_structured_learning as nsl
import tensorflow.keras.callbacks as tkc,\
tensorflow.keras.utils as tku,tensorflow.keras.layers as tkl
from torch.utils.data import DataLoader as tdl
from torch.utils.data import Dataset as tds
from torchvision import transforms,utils,models
import torch.nn.functional as tnnf,torch.nn as tnn
dev=torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
tmodel=models.vgg16(pretrained=True,progress=False)
from IPython.core.magic import register_line_magic
#@tf.autograph.experimental.do_not_convert
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth

# %% [markdown]
#  ## ✒️ &nbsp; Data Loading and Preprocessing

# %%
file_path='https://raw.githubusercontent.com/'+\
          'OlgaBelitskaya/data_kitchen/main/'
file_name='TomatoCultivars160.h5'; img_size=160
def get_file(file_path,file_name):
    input_file=urllib.request.urlopen(file_path+file_name)
    output_file=open(file_name,'wb')
    output_file.write(input_file.read())
    output_file.close(); input_file.close()
get_file(file_path,file_name)
with h5py.File(file_name,'r') as f:
    keys=list(f.keys())
    display(HTML('<p>file keys: '+', '.join(keys)+'</p>'))
    images=np.array(f[keys[0]])
    images=tf.image.resize(images,[img_size,img_size]).numpy()
    labels=np.array(f[keys[1]],dtype='float32')
    names=[el.decode('utf-8') for el in f[keys[2]]]
    f.close()
# Out:
# <p>file keys: images, labels, names</p>

# %%
N=labels.shape[0]; n=int(.1*N)
num_classes=len(names)
shuffle_ids=np.arange(N)
np.random.RandomState(12).shuffle(shuffle_ids)
images=images[shuffle_ids]; labels=labels[shuffle_ids]
x_test,x_valid,x_train=images[:n],images[n:2*n],images[2*n:]
y_test,y_valid,y_train=labels[:n],labels[n:2*n],labels[2*n:]
df=pd.DataFrame(
    [[x_train.shape,x_valid.shape,x_test.shape],
     [x_train.dtype,x_valid.dtype,x_test.dtype],
     [y_train.shape,y_valid.shape,y_test.shape],
     [y_train.dtype,y_valid.dtype,y_test.dtype]],
    columns=['train','valid','test'],
    index=['image shape','image type','label shape','label type'])
def display_imgs(images,labels,names,n=12):
    fig=pl.figure(figsize=(12,3))
    for i in range(0,n):
        ax=fig.add_subplot(2,n//2,i+1,xticks=[],yticks=[])
        ax.set_title(
            names[int(labels[i])],color='slategray',
            fontdict={'fontsize':'large'})
        ax.imshow((images[i]))
    pl.tight_layout(); pl.show()
display_imgs(images,labels,names); display(df)
# Out:
#                           train              valid               test
# image shape  (622, 160, 160, 3)  (77, 160, 160, 3)  (77, 160, 160, 3)
# image type              float32            float32            float32
# label shape              (622,)              (77,)              (77,)
# label type              float32            float32            float32

# %%
class TData(tds):
    def __init__(self,x,y):
        self.x=torch.tensor(x,dtype=torch.float32)
        self.y=torch.tensor(y,dtype=torch.int32)
    def __getitem__(self,index):
        img,lbl=self.x[index],self.y[index]
        return img,lbl
    def __len__(self):
        return self.y.shape[0]
batch_size2=8
n_train=batch_size2*(x_train.shape[0]//batch_size2)
x_train2=np.transpose(x_train,(0,3,1,2))[:n_train]
print(x_train2.mean(),x_train2.std())
n_valid=batch_size2*(x_valid.shape[0]//batch_size2)
x_valid2=np.transpose(x_valid,(0,3,1,2))[:n_valid]
n_test=batch_size2*(x_test.shape[0]//batch_size2)
x_test2=np.transpose(x_test,(0,3,1,2))[:n_test]
random_seed=23
train2=TData(x_train2,y_train[:n_train])
valid2=TData(x_valid2,y_valid[:n_valid])
test2=TData(x_test2,y_test[:n_test])
dataloaders={'train':tdl(dataset=train2,shuffle=True,batch_size=batch_size2),
             'valid':tdl(dataset=valid2,shuffle=True,batch_size=batch_size2),
             'test':tdl(dataset=test2,shuffle=True,batch_size=batch_size2)}
# Out:
# 0.43815878 0.2930987

# %%
@register_line_magic
def display_data_imgs(data):
    global names
    for images,labels in dataloaders[data]:
        print('image dimensions: %s'%str(images.shape))
        print('label dimensions: %s'%str(labels.shape))
        images=[np.transpose(images[i],(1,2,0))
                for i in range(len(images))]
        display_imgs(images,labels,names,8)
        break
# %display_data_imgs valid
# Out:
# image dimensions: torch.Size([8, 3, 160, 160])
# label dimensions: torch.Size([8])

# %% [markdown]
# ## ✒️ &nbsp; Classifiers
# ### Sklearn Algorithms

# %%
def classifier_fit_score(classifier,x_train,x_test,y_train,y_test):
    classifier.fit(x_train,y_train)
    y_clf_train=classifier.predict(x_train)
    y_clf_test=classifier.predict(x_test)
    acc_clf_train=round(accuracy_score(y_train,y_clf_train),4)
    acc_clf_test=round(accuracy_score(y_test,y_clf_test),4)
    loss_clf_train=round(hamming_loss(y_train,y_clf_train),4)
    loss_clf_test=round(hamming_loss(y_test,y_clf_test),4)
    return [y_clf_train,y_clf_test,acc_clf_train,acc_clf_test,
            loss_clf_train,loss_clf_test]
[y_srfc_train,y_srfc_test,acc_srfc_train,
 acc_srfc_test,loss_srfc_train,loss_srfc_test]=\
classifier_fit_score(
    sRFC(),x_train.reshape(-1,3*img_size**2),
    x_test.reshape(-1,3*img_size**2),y_train,y_test)
print(classification_report(y_test,y_srfc_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.75      0.60      0.67         5
#          1.0       0.71      0.62      0.67         8
#          2.0       0.15      0.67      0.25         3
#          3.0       0.43      0.60      0.50         5
#          4.0       0.50      0.50      0.50         2
#          5.0       0.36      0.44      0.40         9
#          6.0       0.00      0.00      0.00         6
#          7.0       0.44      0.67      0.53         6
#          8.0       0.00      0.00      0.00         6
#          9.0       0.25      0.25      0.25         4
#         10.0       0.29      1.00      0.44         2
#         11.0       0.33      0.14      0.20         7
#         12.0       0.14      0.33      0.20         3
#         13.0       0.50      0.20      0.29         5
#         14.0       0.00      0.00      0.00         6
#
#     accuracy                           0.36        77
#    macro avg       0.32      0.40      0.33        77
# weighted avg       0.34      0.36      0.33        77

# %%
def plot_predict(y_predict,label_predict,t=30,fig_size=12):
    pl.figure(figsize=(fig_size,fig_size//4)); x=range(t)
    pl.scatter(x,y_test[:t],marker='*',s=100,
               color='slategray',label='Real data')
    pl.scatter(x,y_predict[:t],marker='v',s=50,
               color='#348ABD',label=label_predict)
    pl.xlabel('Observations'); pl.ylabel('Targets')
    pl.title('Classifiers. Test Results',color='slategray',
             fontdict={'fontsize':'large'})
    pl.legend(loc=2,fontsize=10)
    pl.tight_layout; pl.show()
plot_predict(y_srfc_test,'Random Forest')

# %% [markdown]
# CNN Based Models with Adversarial Regularization

# %%
batch_size=64; epochs=30
base_model=tf.keras.Sequential([
    tkl.Input((img_size,img_size,3),name='input'),
    tkl.Conv2D(32,(5,5),padding='same'),
    tkl.Activation('relu'),
    tkl.MaxPooling2D(pool_size=(2,2)),
    tkl.Dropout(.25),
    tkl.Conv2D(196,(5,5)),
    tkl.Activation('relu'),
    tkl.MaxPooling2D(pool_size=(2,2)),
    tkl.Dropout(.25),
    tkl.GlobalMaxPooling2D(),
    tkl.Dense(512),
    tkl.Activation('relu'),
    tkl.Dropout(.25),
    tkl.Dense(128),
    tkl.Activation('relu'),
    tkl.Dropout(.25),
    tkl.Dense(num_classes,activation='softmax')])
adv_config=nsl.configs\
.make_adv_reg_config(multiplier=.2,adv_step_size=.05)
adv_model=nsl.keras\
.AdversarialRegularization(base_model,adv_config=adv_config)
model_weights='/tmp/checkpoint'
checkpointer=tkc.ModelCheckpoint(
    filepath=model_weights,verbose=2,save_weights_only=True,
    monitor='val_sparse_categorical_accuracy',
    mode='max',save_best_only=True)
adv_model.compile(optimizer='nadam',metrics=['accuracy'],
                  loss='sparse_categorical_crossentropy')

# %%
train=tf.data.Dataset.from_tensor_slices(
    {'input':x_train,'label':y_train}).batch(batch_size)
valid=tf.data.Dataset.from_tensor_slices(
    {'input':x_valid,'label':y_valid}).batch(batch_size)
valid_steps=x_valid.shape[0]//batch_size
adv_model.fit(train,validation_data=valid,
              verbose=2,callbacks=[checkpointer],
              validation_steps=valid_steps,epochs=epochs);
# Out:
# Epoch 1/30
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7f5591d2bf30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:absl:Cannot perturb features dict_keys(['label'])
# WARNING:tensorflow:AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7f5591d2bf30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <bound method Socket.send of <zmq.sugar.socket.Socket object at 0x7f5591d2bf30>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module, class, method, function, traceback, frame, or code object was expected, got cython_function_or_method
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function wrap at 0x7f55ad5dacb0> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function wrap at 0x7f55ad5dacb0> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function wrap at 0x7f55ad5dacb0> and will run it as-is.
# Cause: while/else statement not yet supported
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 10/10 - 54s - loss: 3.2471 - sparse_categorical_crossentropy: 2.7066 - sparse_categorical_accuracy: 0.0949 - scaled_adversarial_loss: 0.5404 - val_loss: 3.2209 - val_sparse_categorical_crossentropy: 2.6836 - val_sparse_categorical_accuracy: 0.1094 - val_scaled_adversarial_loss: 0.5374
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.10938, saving model to /tmp/checkpoint
# Epoch 2/30
# 10/10 - 2s - loss: 3.0238 - sparse_categorical_crossentropy: 2.5196 - sparse_categorical_accuracy: 0.1463 - scaled_adversarial_loss: 0.5042 - val_loss: 2.9126 - val_sparse_categorical_crossentropy: 2.4262 - val_sparse_categorical_accuracy: 0.1250 - val_scaled_adversarial_loss: 0.4865
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.10938 to 0.12500, saving model to /tmp/checkpoint
# Epoch 3/30
# 10/10 - 2s - loss: 2.7182 - sparse_categorical_crossentropy: 2.2707 - sparse_categorical_accuracy: 0.1913 - scaled_adversarial_loss: 0.4475 - val_loss: 2.7067 - val_sparse_categorical_crossentropy: 2.2537 - val_sparse_categorical_accuracy: 0.1719 - val_scaled_adversarial_loss: 0.4530
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.12500 to 0.17188, saving model to /tmp/checkpoint
# Epoch 4/30
# 10/10 - 2s - loss: 2.4696 - sparse_categorical_crossentropy: 2.0564 - sparse_categorical_accuracy: 0.2235 - scaled_adversarial_loss: 0.4132 - val_loss: 2.4064 - val_sparse_categorical_crossentropy: 2.0028 - val_sparse_categorical_accuracy: 0.2969 - val_scaled_adversarial_loss: 0.4036
#
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.17188 to 0.29688, saving model to /tmp/checkpoint
# Epoch 5/30
# 10/10 - 2s - loss: 2.4231 - sparse_categorical_crossentropy: 2.0174 - sparse_categorical_accuracy: 0.2154 - scaled_adversarial_loss: 0.4057 - val_loss: 2.3810 - val_sparse_categorical_crossentropy: 1.9820 - val_sparse_categorical_accuracy: 0.2969 - val_scaled_adversarial_loss: 0.3990
#
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.29688
# Epoch 6/30
# 10/10 - 2s - loss: 2.2497 - sparse_categorical_crossentropy: 1.8715 - sparse_categorical_accuracy: 0.2653 - scaled_adversarial_loss: 0.3782 - val_loss: 2.2169 - val_sparse_categorical_crossentropy: 1.8444 - val_sparse_categorical_accuracy: 0.3438 - val_scaled_adversarial_loss: 0.3725

# %%
adv_model.load_weights(model_weights)
adv_model.evaluate({'input':x_test,'label':y_test})
# Out:
# 3/3 [==============================] - 2s 212ms/step - loss: 1.8804 - sparse_categorical_crossentropy: 1.5605 - sparse_categorical_accuracy: 0.4545 - scaled_adversarial_loss: 0.3199
# [1.880401611328125,
#  1.5604709386825562,
#  0.4545454680919647,
#  0.31993067264556885]

# %% [markdown]
# ### TFHub Models

# %%
def premodel(img_size,den,mh,num_classes):
    model=tf.keras.Sequential([
        tf.keras.layers.Input((img_size,img_size,3),name='input'),
        th.KerasLayer(mh,trainable=True),
        tkl.Flatten(),
        tkl.Dense(den,activation='relu'),
        tkl.Dropout(rate=.5),
        tkl.Dense(num_classes,activation='softmax')])
    model.compile(optimizer='nadam',metrics=['accuracy'],
                  loss='sparse_categorical_crossentropy')
    display(model.summary())
    return model
def cb(model_weights):
    early_stopping=tkc.EarlyStopping(
        monitor='val_loss',patience=20,verbose=2)
    checkpointer=tkc.ModelCheckpoint(
    filepath=model_weights,verbose=2,save_weights_only=True,
    monitor='val_accuracy',mode='max',save_best_only=True)
    lr_reduction=tkc.ReduceLROnPlateau(
        monitor='val_loss',verbose=2,patience=5,factor=.8)
    return [checkpointer,early_stopping,lr_reduction]

# %%
handle_base='mobilenet_v2_075_160'
mhandle='https://tfhub.dev/google/imagenet/{}/feature_vector/4'\
.format(handle_base)

# %%
model=premodel(img_size,1024,mhandle,num_classes)
history=model.fit(x=x_train,y=y_train,batch_size=32,
                  epochs=70,callbacks=cb(model_weights),
                  validation_data=(x_valid,y_valid))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer (KerasLayer)     (None, 1280)              1382064
# _________________________________________________________________
# flatten (Flatten)            (None, 1280)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1024)              1311744
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 15)                15375
# =================================================================
# Total params: 2,709,183
# Trainable params: 2,682,543
# Non-trainable params: 26,640
# _________________________________________________________________
# None
# Epoch 1/70
# 20/20 [==============================] - 16s 181ms/step - loss: 2.4266 - accuracy: 0.3202 - val_loss: 2.4586 - val_accuracy: 0.3896
#
# Epoch 00001: val_accuracy improved from -inf to 0.38961, saving model to /tmp/checkpoint
# Epoch 2/70
# 20/20 [==============================] - 2s 109ms/step - loss: 0.6815 - accuracy: 0.7959 - val_loss: 2.1735 - val_accuracy: 0.5714
#
# Epoch 00002: val_accuracy improved from 0.38961 to 0.57143, saving model to /tmp/checkpoint
# Epoch 3/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.4413 - accuracy: 0.8798 - val_loss: 1.4335 - val_accuracy: 0.6753
#
# Epoch 00003: val_accuracy improved from 0.57143 to 0.67532, saving model to /tmp/checkpoint
# Epoch 4/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.4797 - accuracy: 0.8755 - val_loss: 2.4379 - val_accuracy: 0.5974
#
# Epoch 00004: val_accuracy did not improve from 0.67532
# Epoch 5/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.4769 - accuracy: 0.8811 - val_loss: 2.3637 - val_accuracy: 0.5844
#
# Epoch 00005: val_accuracy did not improve from 0.67532
# Epoch 6/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.6014 - accuracy: 0.8438 - val_loss: 5.3383 - val_accuracy: 0.4675
#
# Epoch 00006: val_accuracy did not improve from 0.67532
# Epoch 7/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.2848 - accuracy: 0.9375 - val_loss: 3.5440 - val_accuracy: 0.5584
#
# Epoch 00007: val_accuracy did not improve from 0.67532
# Epoch 8/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.5721 - accuracy: 0.8774 - val_loss: 3.9739 - val_accuracy: 0.5714
#
# Epoch 00008: val_accuracy did not improve from 0.67532
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 9/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.4113 - accuracy: 0.9128 - val_loss: 3.6901 - val_accuracy: 0.5455
#
# Epoch 00009: val_accuracy did not improve from 0.67532
# Epoch 10/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.2591 - accuracy: 0.9541 - val_loss: 2.7580 - val_accuracy: 0.5584
#
# Epoch 00010: val_accuracy did not improve from 0.67532
# Epoch 11/70
# 20/20 [==============================] - 2s 113ms/step - loss: 0.2962 - accuracy: 0.9462 - val_loss: 1.4995 - val_accuracy: 0.7403
#
# Epoch 00011: val_accuracy improved from 0.67532 to 0.74026, saving model to /tmp/checkpoint
# Epoch 12/70
# 20/20 [==============================] - 2s 114ms/step - loss: 0.2137 - accuracy: 0.9646 - val_loss: 1.2312 - val_accuracy: 0.8052
#
# Epoch 00012: val_accuracy improved from 0.74026 to 0.80519, saving model to /tmp/checkpoint
# Epoch 13/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.1272 - accuracy: 0.9901 - val_loss: 1.4046 - val_accuracy: 0.7532
#
# Epoch 00013: val_accuracy did not improve from 0.80519
# Epoch 14/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.1072 - accuracy: 0.9847 - val_loss: 1.4431 - val_accuracy: 0.7922
#
# Epoch 00014: val_accuracy did not improve from 0.80519
# Epoch 15/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.1357 - accuracy: 0.9857 - val_loss: 1.4739 - val_accuracy: 0.8052
#
# Epoch 00015: val_accuracy did not improve from 0.80519
# Epoch 16/70
# 20/20 [==============================] - 2s 109ms/step - loss: 0.1927 - accuracy: 0.9656 - val_loss: 1.1364 - val_accuracy: 0.8312
#
# Epoch 00016: val_accuracy improved from 0.80519 to 0.83117, saving model to /tmp/checkpoint
# Epoch 17/70
# 20/20 [==============================] - 2s 113ms/step - loss: 0.1394 - accuracy: 0.9833 - val_loss: 1.3647 - val_accuracy: 0.7792
#
# Epoch 00017: val_accuracy did not improve from 0.83117
# Epoch 18/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.1264 - accuracy: 0.9809 - val_loss: 1.7295 - val_accuracy: 0.7143
#
# Epoch 00018: val_accuracy did not improve from 0.83117
# Epoch 19/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.4872 - accuracy: 0.9096 - val_loss: 1.9591 - val_accuracy: 0.6883
#
# Epoch 00019: val_accuracy did not improve from 0.83117
# Epoch 20/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.3474 - accuracy: 0.9327 - val_loss: 1.7099 - val_accuracy: 0.7662
#
# Epoch 00020: val_accuracy did not improve from 0.83117
# Epoch 21/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.1819 - accuracy: 0.9570 - val_loss: 1.1242 - val_accuracy: 0.7922
#
# Epoch 00021: val_accuracy did not improve from 0.83117
# Epoch 22/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.1542 - accuracy: 0.9775 - val_loss: 1.1984 - val_accuracy: 0.7013
#
# Epoch 00022: val_accuracy did not improve from 0.83117
# Epoch 23/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0952 - accuracy: 0.9920 - val_loss: 1.5697 - val_accuracy: 0.7273
#
# Epoch 00023: val_accuracy did not improve from 0.83117
# Epoch 24/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.1346 - accuracy: 0.9803 - val_loss: 1.7058 - val_accuracy: 0.7403
#
# Epoch 00024: val_accuracy did not improve from 0.83117
# Epoch 25/70
# 20/20 [==============================] - 2s 109ms/step - loss: 0.3974 - accuracy: 0.9217 - val_loss: 3.1215 - val_accuracy: 0.5844
#
# Epoch 00025: val_accuracy did not improve from 0.83117
# Epoch 26/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.4000 - accuracy: 0.9200 - val_loss: 3.7213 - val_accuracy: 0.5195
#
# Epoch 00026: val_accuracy did not improve from 0.83117
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 27/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.3892 - accuracy: 0.9452 - val_loss: 1.2907 - val_accuracy: 0.6753
#
# Epoch 00027: val_accuracy did not improve from 0.83117
# Epoch 28/70
# 20/20 [==============================] - 2s 108ms/step - loss: 0.1526 - accuracy: 0.9794 - val_loss: 1.2040 - val_accuracy: 0.7143
#
# Epoch 00028: val_accuracy did not improve from 0.83117
# Epoch 29/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.1004 - accuracy: 0.9809 - val_loss: 1.1752 - val_accuracy: 0.7143
#
# Epoch 00029: val_accuracy did not improve from 0.83117
# Epoch 30/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.1665 - accuracy: 0.9824 - val_loss: 1.1285 - val_accuracy: 0.7273
#
# Epoch 00030: val_accuracy did not improve from 0.83117
# Epoch 31/70
# 20/20 [==============================] - 2s 109ms/step - loss: 0.0841 - accuracy: 0.9945 - val_loss: 0.9994 - val_accuracy: 0.7662
#
# Epoch 00031: val_accuracy did not improve from 0.83117
# Epoch 32/70
# 20/20 [==============================] - 2s 113ms/step - loss: 0.1634 - accuracy: 0.9808 - val_loss: 1.4353 - val_accuracy: 0.7273
#
# Epoch 00032: val_accuracy did not improve from 0.83117
# Epoch 33/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.2006 - accuracy: 0.9687 - val_loss: 1.8283 - val_accuracy: 0.6494
#
# Epoch 00033: val_accuracy did not improve from 0.83117
# Epoch 34/70
# 20/20 [==============================] - 2s 109ms/step - loss: 0.1534 - accuracy: 0.9854 - val_loss: 2.5155 - val_accuracy: 0.6623
#
# Epoch 00034: val_accuracy did not improve from 0.83117
# Epoch 35/70
# 20/20 [==============================] - 2s 113ms/step - loss: 0.1254 - accuracy: 0.9747 - val_loss: 1.5968 - val_accuracy: 0.7143
#
# Epoch 00035: val_accuracy did not improve from 0.83117
# Epoch 36/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.1115 - accuracy: 0.9887 - val_loss: 1.0754 - val_accuracy: 0.7403
#
# Epoch 00036: val_accuracy did not improve from 0.83117
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 37/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0833 - accuracy: 0.9948 - val_loss: 1.2801 - val_accuracy: 0.7532
#
# Epoch 00037: val_accuracy did not improve from 0.83117
# Epoch 38/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0833 - accuracy: 0.9957 - val_loss: 1.4192 - val_accuracy: 0.7273
#
# Epoch 00038: val_accuracy did not improve from 0.83117
# Epoch 39/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0913 - accuracy: 0.9945 - val_loss: 1.4528 - val_accuracy: 0.7143
#
# Epoch 00039: val_accuracy did not improve from 0.83117
# Epoch 40/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0758 - accuracy: 0.9996 - val_loss: 1.3750 - val_accuracy: 0.7532
#
# Epoch 00040: val_accuracy did not improve from 0.83117
# Epoch 41/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0806 - accuracy: 0.9972 - val_loss: 1.2690 - val_accuracy: 0.7273
#
# Epoch 00041: val_accuracy did not improve from 0.83117
#
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 42/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0717 - accuracy: 1.0000 - val_loss: 1.1842 - val_accuracy: 0.7403
#
# Epoch 00042: val_accuracy did not improve from 0.83117
# Epoch 43/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0879 - accuracy: 0.9906 - val_loss: 1.1039 - val_accuracy: 0.7662
#
# Epoch 00043: val_accuracy did not improve from 0.83117
# Epoch 44/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0723 - accuracy: 1.0000 - val_loss: 1.1043 - val_accuracy: 0.7922
#
# Epoch 00044: val_accuracy did not improve from 0.83117
# Epoch 45/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0693 - accuracy: 0.9989 - val_loss: 1.1285 - val_accuracy: 0.7922
#
# Epoch 00045: val_accuracy did not improve from 0.83117
# Epoch 46/70
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0679 - accuracy: 0.9998 - val_loss: 1.0095 - val_accuracy: 0.7922
#
# Epoch 00046: val_accuracy did not improve from 0.83117
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 47/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0727 - accuracy: 0.9989 - val_loss: 1.0304 - val_accuracy: 0.8052
#
# Epoch 00047: val_accuracy did not improve from 0.83117
# Epoch 48/70
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0685 - accuracy: 1.0000 - val_loss: 1.0317 - val_accuracy: 0.8052
#
# Epoch 00048: val_accuracy did not improve from 0.83117
# Epoch 49/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0696 - accuracy: 0.9985 - val_loss: 1.0474 - val_accuracy: 0.8052
#
# Epoch 00049: val_accuracy did not improve from 0.83117
# Epoch 50/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0811 - accuracy: 0.9949 - val_loss: 1.0649 - val_accuracy: 0.8312
#
# Epoch 00050: val_accuracy did not improve from 0.83117
# Epoch 51/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0695 - accuracy: 0.9991 - val_loss: 0.8831 - val_accuracy: 0.8571
#
# Epoch 00051: val_accuracy improved from 0.83117 to 0.85714, saving model to /tmp/checkpoint
# Epoch 52/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0695 - accuracy: 1.0000 - val_loss: 0.8138 - val_accuracy: 0.8571
#
# Epoch 00052: val_accuracy did not improve from 0.85714
# Epoch 53/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.8224 - val_accuracy: 0.8442
#
# Epoch 00053: val_accuracy did not improve from 0.85714
# Epoch 54/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0724 - accuracy: 0.9980 - val_loss: 0.8906 - val_accuracy: 0.8571
#
# Epoch 00054: val_accuracy did not improve from 0.85714
# Epoch 55/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0676 - accuracy: 1.0000 - val_loss: 0.8639 - val_accuracy: 0.8571
#
# Epoch 00055: val_accuracy did not improve from 0.85714
# Epoch 56/70
# 20/20 [==============================] - 2s 113ms/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 0.8407 - val_accuracy: 0.8571
#
# Epoch 00056: val_accuracy did not improve from 0.85714
# Epoch 57/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0692 - accuracy: 1.0000 - val_loss: 0.8318 - val_accuracy: 0.8571
#
# Epoch 00057: val_accuracy did not improve from 0.85714
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 58/70
# 20/20 [==============================] - 2s 109ms/step - loss: 0.0670 - accuracy: 1.0000 - val_loss: 0.8380 - val_accuracy: 0.8571
#
# Epoch 00058: val_accuracy did not improve from 0.85714
# Epoch 59/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0802 - accuracy: 0.9922 - val_loss: 0.8506 - val_accuracy: 0.8312
#
# Epoch 00059: val_accuracy did not improve from 0.85714
# Epoch 60/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 0.8443 - val_accuracy: 0.8182
#
# Epoch 00060: val_accuracy did not improve from 0.85714
# Epoch 61/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0702 - accuracy: 0.9996 - val_loss: 0.8377 - val_accuracy: 0.8312
#
# Epoch 00061: val_accuracy did not improve from 0.85714
# Epoch 62/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0675 - accuracy: 0.9998 - val_loss: 0.8610 - val_accuracy: 0.8182
#
# Epoch 00062: val_accuracy did not improve from 0.85714
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 63/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0674 - accuracy: 1.0000 - val_loss: 0.8766 - val_accuracy: 0.8312
#
# Epoch 00063: val_accuracy did not improve from 0.85714
# Epoch 64/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 0.8770 - val_accuracy: 0.8312
#
# Epoch 00064: val_accuracy did not improve from 0.85714
# Epoch 65/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0690 - accuracy: 1.0000 - val_loss: 0.8570 - val_accuracy: 0.8182
#
# Epoch 00065: val_accuracy did not improve from 0.85714
# Epoch 66/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0669 - accuracy: 1.0000 - val_loss: 0.8592 - val_accuracy: 0.8312
#
# Epoch 00066: val_accuracy did not improve from 0.85714
# Epoch 67/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0670 - accuracy: 1.0000 - val_loss: 0.8581 - val_accuracy: 0.8182
#
# Epoch 00067: val_accuracy did not improve from 0.85714
#
# Epoch 00067: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# Epoch 68/70
# 20/20 [==============================] - 2s 111ms/step - loss: 0.0668 - accuracy: 1.0000 - val_loss: 0.8594 - val_accuracy: 0.8182
#
# Epoch 00068: val_accuracy did not improve from 0.85714
# Epoch 69/70
# 20/20 [==============================] - 2s 112ms/step - loss: 0.0680 - accuracy: 0.9996 - val_loss: 0.8827 - val_accuracy: 0.8442
#
# Epoch 00069: val_accuracy did not improve from 0.85714
# Epoch 70/70
# 20/20 [==============================] - 2s 110ms/step - loss: 0.0672 - accuracy: 1.0000 - val_loss: 0.9050 - val_accuracy: 0.8312
#
# Epoch 00070: val_accuracy did not improve from 0.85714

# %%
model.load_weights(model_weights)
model.evaluate(x_test,y_test)
# Out:
# 3/3 [==============================] - 0s 15ms/step - loss: 1.2535 - accuracy: 0.8571
# [1.2535418272018433, 0.8571428656578064]

# %%
y_mob_test=np.argmax(model.predict(x_test),axis=-1)
plot_predict(y_mob_test,'MobileNet')

# %%
handle_base='inception_v3'
mhandle='https://tfhub.dev/google/imagenet/{}/classification/4'\
.format(handle_base)

# %%
model=premodel(img_size,1024,mhandle,num_classes)
history=model.fit(x=x_train,y=y_train,batch_size=32,
                  epochs=70,callbacks=cb(model_weights),
                  validation_data=(x_valid,y_valid))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# keras_layer_1 (KerasLayer)   (None, 1001)              23853833
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1001)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1024)              1026048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 15)                15375
# =================================================================
# Total params: 24,895,256
# Trainable params: 24,860,824
# Non-trainable params: 34,432
# _________________________________________________________________
# None
# Epoch 1/70
# 20/20 [==============================] - 26s 361ms/step - loss: 3.3230 - accuracy: 0.1613 - val_loss: 6.9387 - val_accuracy: 0.0519
#
# Epoch 00001: val_accuracy improved from -inf to 0.05195, saving model to /tmp/checkpoint
# Epoch 2/70
# 20/20 [==============================] - 3s 168ms/step - loss: 1.9962 - accuracy: 0.5489 - val_loss: 4.2726 - val_accuracy: 0.1429
#
# Epoch 00002: val_accuracy improved from 0.05195 to 0.14286, saving model to /tmp/checkpoint
# Epoch 3/70
# 20/20 [==============================] - 3s 168ms/step - loss: 1.3181 - accuracy: 0.7056 - val_loss: 8.9485 - val_accuracy: 0.1558
#
# Epoch 00003: val_accuracy improved from 0.14286 to 0.15584, saving model to /tmp/checkpoint
# Epoch 4/70
# 20/20 [==============================] - 3s 168ms/step - loss: 1.2699 - accuracy: 0.7448 - val_loss: 10.9553 - val_accuracy: 0.1818
#
# Epoch 00004: val_accuracy improved from 0.15584 to 0.18182, saving model to /tmp/checkpoint
# Epoch 5/70
# 20/20 [==============================] - 3s 169ms/step - loss: 1.2710 - accuracy: 0.7313 - val_loss: 16.0588 - val_accuracy: 0.1429
#
# Epoch 00005: val_accuracy did not improve from 0.18182
# Epoch 6/70
# 20/20 [==============================] - 3s 169ms/step - loss: 1.0168 - accuracy: 0.7870 - val_loss: 8.1085 - val_accuracy: 0.3247
#
# Epoch 00006: val_accuracy improved from 0.18182 to 0.32468, saving model to /tmp/checkpoint
# Epoch 7/70
# 20/20 [==============================] - 3s 169ms/step - loss: 0.8582 - accuracy: 0.8482 - val_loss: 6.3416 - val_accuracy: 0.4026
#
# Epoch 00007: val_accuracy improved from 0.32468 to 0.40260, saving model to /tmp/checkpoint
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# Epoch 8/70
# 20/20 [==============================] - 3s 170ms/step - loss: 0.9205 - accuracy: 0.8347 - val_loss: 4.5537 - val_accuracy: 0.4416
#
# Epoch 00008: val_accuracy improved from 0.40260 to 0.44156, saving model to /tmp/checkpoint
# Epoch 9/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.7432 - accuracy: 0.8961 - val_loss: 7.5478 - val_accuracy: 0.3506
#
# Epoch 00009: val_accuracy did not improve from 0.44156
# Epoch 10/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.5484 - accuracy: 0.9099 - val_loss: 12.2388 - val_accuracy: 0.3896
#
# Epoch 00010: val_accuracy did not improve from 0.44156
# Epoch 11/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.6782 - accuracy: 0.9025 - val_loss: 2.4333 - val_accuracy: 0.6234
#
# Epoch 00011: val_accuracy improved from 0.44156 to 0.62338, saving model to /tmp/checkpoint
# Epoch 12/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.5272 - accuracy: 0.9467 - val_loss: 4.7655 - val_accuracy: 0.5584
#
# Epoch 00012: val_accuracy did not improve from 0.62338
# Epoch 13/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.4649 - accuracy: 0.9601 - val_loss: 3.3727 - val_accuracy: 0.5844
#
# Epoch 00013: val_accuracy did not improve from 0.62338
# Epoch 14/70
# 20/20 [==============================] - 3s 166ms/step - loss: 0.5063 - accuracy: 0.9385 - val_loss: 3.6578 - val_accuracy: 0.5974
#
# Epoch 00014: val_accuracy did not improve from 0.62338
# Epoch 15/70
# 20/20 [==============================] - 3s 166ms/step - loss: 0.4603 - accuracy: 0.9726 - val_loss: 4.7667 - val_accuracy: 0.5455
#
# Epoch 00015: val_accuracy did not improve from 0.62338
# Epoch 16/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.9049 - accuracy: 0.8446 - val_loss: 10.0547 - val_accuracy: 0.2987
#
# Epoch 00016: val_accuracy did not improve from 0.62338
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# Epoch 17/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.5733 - accuracy: 0.9319 - val_loss: 3.8153 - val_accuracy: 0.5974
#
# Epoch 00017: val_accuracy did not improve from 0.62338
# Epoch 18/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.5049 - accuracy: 0.9538 - val_loss: 2.5159 - val_accuracy: 0.5584
#
# Epoch 00018: val_accuracy did not improve from 0.62338
# Epoch 19/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.4165 - accuracy: 0.9589 - val_loss: 2.9101 - val_accuracy: 0.5714
#
# Epoch 00019: val_accuracy did not improve from 0.62338
# Epoch 20/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.4650 - accuracy: 0.9493 - val_loss: 1.7070 - val_accuracy: 0.6753
#
# Epoch 00020: val_accuracy improved from 0.62338 to 0.67532, saving model to /tmp/checkpoint
# Epoch 21/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.3416 - accuracy: 0.9888 - val_loss: 1.4679 - val_accuracy: 0.7532
#
# Epoch 00021: val_accuracy improved from 0.67532 to 0.75325, saving model to /tmp/checkpoint
# Epoch 22/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.4862 - accuracy: 0.9652 - val_loss: 1.9041 - val_accuracy: 0.6623
#
# Epoch 00022: val_accuracy did not improve from 0.75325
# Epoch 23/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.4811 - accuracy: 0.9480 - val_loss: 2.7950 - val_accuracy: 0.5714
#
# Epoch 00023: val_accuracy did not improve from 0.75325
# Epoch 24/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3911 - accuracy: 0.9746 - val_loss: 1.9024 - val_accuracy: 0.6883
#
# Epoch 00024: val_accuracy did not improve from 0.75325
# Epoch 25/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.3691 - accuracy: 0.9808 - val_loss: 2.2064 - val_accuracy: 0.6494
#
# Epoch 00025: val_accuracy did not improve from 0.75325
# Epoch 26/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3267 - accuracy: 0.9935 - val_loss: 2.1080 - val_accuracy: 0.7013
#
# Epoch 00026: val_accuracy did not improve from 0.75325
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# Epoch 27/70
# 20/20 [==============================] - 3s 169ms/step - loss: 0.4477 - accuracy: 0.9682 - val_loss: 1.9122 - val_accuracy: 0.6364
#
# Epoch 00027: val_accuracy did not improve from 0.75325
# Epoch 28/70
# 20/20 [==============================] - 3s 169ms/step - loss: 0.3978 - accuracy: 0.9691 - val_loss: 3.2402 - val_accuracy: 0.5844
#
# Epoch 00028: val_accuracy did not improve from 0.75325
# Epoch 29/70
# 20/20 [==============================] - 3s 169ms/step - loss: 0.5917 - accuracy: 0.9443 - val_loss: 1.9770 - val_accuracy: 0.6234
#
# Epoch 00029: val_accuracy did not improve from 0.75325
# Epoch 30/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.4070 - accuracy: 0.9701 - val_loss: 1.8035 - val_accuracy: 0.7013
#
# Epoch 00030: val_accuracy did not improve from 0.75325
# Epoch 31/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.4051 - accuracy: 0.9721 - val_loss: 1.6994 - val_accuracy: 0.7792
#
# Epoch 00031: val_accuracy improved from 0.75325 to 0.77922, saving model to /tmp/checkpoint
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# Epoch 32/70
# 20/20 [==============================] - 3s 169ms/step - loss: 0.3286 - accuracy: 0.9925 - val_loss: 1.5669 - val_accuracy: 0.7922
#
# Epoch 00032: val_accuracy improved from 0.77922 to 0.79221, saving model to /tmp/checkpoint
# Epoch 33/70
# 20/20 [==============================] - 3s 169ms/step - loss: 0.3351 - accuracy: 0.9902 - val_loss: 1.3889 - val_accuracy: 0.7403
#
# Epoch 00033: val_accuracy did not improve from 0.79221
# Epoch 34/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3464 - accuracy: 0.9811 - val_loss: 1.5879 - val_accuracy: 0.7143
#
# Epoch 00034: val_accuracy did not improve from 0.79221
# Epoch 35/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3317 - accuracy: 0.9902 - val_loss: 1.5431 - val_accuracy: 0.7532
#
# Epoch 00035: val_accuracy did not improve from 0.79221
# Epoch 36/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3066 - accuracy: 0.9953 - val_loss: 1.5777 - val_accuracy: 0.7143
#
# Epoch 00036: val_accuracy did not improve from 0.79221
# Epoch 37/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.3399 - accuracy: 0.9894 - val_loss: 1.7748 - val_accuracy: 0.7273
#
# Epoch 00037: val_accuracy did not improve from 0.79221
# Epoch 38/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.3311 - accuracy: 0.9887 - val_loss: 1.5694 - val_accuracy: 0.7273
#
# Epoch 00038: val_accuracy did not improve from 0.79221
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 0.00032768002711236477.
# Epoch 39/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3245 - accuracy: 0.9936 - val_loss: 1.4601 - val_accuracy: 0.7662
#
# Epoch 00039: val_accuracy did not improve from 0.79221
# Epoch 40/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3435 - accuracy: 0.9881 - val_loss: 1.2188 - val_accuracy: 0.8182
#
# Epoch 00040: val_accuracy improved from 0.79221 to 0.81818, saving model to /tmp/checkpoint
# Epoch 41/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3211 - accuracy: 0.9916 - val_loss: 1.1639 - val_accuracy: 0.8052
#
# Epoch 00041: val_accuracy did not improve from 0.81818
# Epoch 42/70
# 20/20 [==============================] - 3s 169ms/step - loss: 0.3073 - accuracy: 0.9967 - val_loss: 1.4585 - val_accuracy: 0.7662
#
# Epoch 00042: val_accuracy did not improve from 0.81818
# Epoch 43/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3152 - accuracy: 0.9955 - val_loss: 1.5488 - val_accuracy: 0.7403
#
# Epoch 00043: val_accuracy did not improve from 0.81818
# Epoch 44/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3039 - accuracy: 0.9979 - val_loss: 1.6304 - val_accuracy: 0.7013
#
# Epoch 00044: val_accuracy did not improve from 0.81818
# Epoch 45/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.2985 - accuracy: 0.9998 - val_loss: 1.5242 - val_accuracy: 0.7143
#
# Epoch 00045: val_accuracy did not improve from 0.81818
# Epoch 46/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.2959 - accuracy: 0.9992 - val_loss: 1.4857 - val_accuracy: 0.7403
#
# Epoch 00046: val_accuracy did not improve from 0.81818
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.0002621440216898918.
# Epoch 47/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3050 - accuracy: 0.9948 - val_loss: 1.5726 - val_accuracy: 0.7532
#
# Epoch 00047: val_accuracy did not improve from 0.81818
# Epoch 48/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.3030 - accuracy: 0.9986 - val_loss: 1.5477 - val_accuracy: 0.7792
#
# Epoch 00048: val_accuracy did not improve from 0.81818
# Epoch 49/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3006 - accuracy: 0.9956 - val_loss: 1.4479 - val_accuracy: 0.7662
#
# Epoch 00049: val_accuracy did not improve from 0.81818
# Epoch 50/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3064 - accuracy: 0.9961 - val_loss: 1.5196 - val_accuracy: 0.7792
#
# Epoch 00050: val_accuracy did not improve from 0.81818
# Epoch 51/70
# 20/20 [==============================] - 3s 167ms/step - loss: 0.3106 - accuracy: 0.9907 - val_loss: 1.6619 - val_accuracy: 0.7662
#
# Epoch 00051: val_accuracy did not improve from 0.81818
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00020971521735191345.
# Epoch 52/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.2961 - accuracy: 0.9995 - val_loss: 1.6513 - val_accuracy: 0.7792
#
# Epoch 00052: val_accuracy did not improve from 0.81818
# Epoch 53/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.2933 - accuracy: 0.9995 - val_loss: 1.5662 - val_accuracy: 0.7792
#
# Epoch 00053: val_accuracy did not improve from 0.81818
# Epoch 54/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.2927 - accuracy: 1.0000 - val_loss: 1.5385 - val_accuracy: 0.7792
#
# Epoch 00054: val_accuracy did not improve from 0.81818
# Epoch 55/70
# 20/20 [==============================] - 3s 169ms/step - loss: 0.2946 - accuracy: 0.9991 - val_loss: 1.5697 - val_accuracy: 0.7792
#
# Epoch 00055: val_accuracy did not improve from 0.81818
# Epoch 56/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.2935 - accuracy: 1.0000 - val_loss: 1.5809 - val_accuracy: 0.7532
#
# Epoch 00056: val_accuracy did not improve from 0.81818
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 0.00016777217388153076.
# Epoch 57/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.2928 - accuracy: 1.0000 - val_loss: 1.5565 - val_accuracy: 0.7662
#
# Epoch 00057: val_accuracy did not improve from 0.81818
# Epoch 58/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.2917 - accuracy: 0.9996 - val_loss: 1.5731 - val_accuracy: 0.7662
#
# Epoch 00058: val_accuracy did not improve from 0.81818
# Epoch 59/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.2953 - accuracy: 1.0000 - val_loss: 1.5046 - val_accuracy: 0.7532
#
# Epoch 00059: val_accuracy did not improve from 0.81818
# Epoch 60/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.3027 - accuracy: 0.9976 - val_loss: 1.5418 - val_accuracy: 0.7403
#
# Epoch 00060: val_accuracy did not improve from 0.81818
# Epoch 61/70
# 20/20 [==============================] - 3s 168ms/step - loss: 0.2948 - accuracy: 0.9963 - val_loss: 1.6658 - val_accuracy: 0.7273
#
# Epoch 00061: val_accuracy did not improve from 0.81818
#
# Epoch 00061: ReduceLROnPlateau reducing learning rate to 0.00013421773910522462.
# Epoch 00061: early stopping

# %%
model.load_weights(model_weights)
model.evaluate(x_test,y_test)
# Out:
# 3/3 [==============================] - 0s 52ms/step - loss: 1.7325 - accuracy: 0.7403
# [1.7324535846710205, 0.7402597665786743]

# %% [markdown]
# ### TorchVision Models

# %%
for param in tmodel.parameters(): param.requires_grad=False
tmodel.classifier[3].requires_grad=True
def model_acc(model,data_loader):
    correct_preds,num_examples=0,0
    for features,targets in data_loader:
        features=features.to(dev)
        targets=targets.to(dev).long()
        logits=model(features)
        _,pred_labels=torch.max(logits,1)
        num_examples+=targets.size(0)
        correct_preds+=(pred_labels==targets).sum()
    return correct_preds.float()/num_examples*100
def epoch_loss(model,data_loader):
    model.eval()
    curr_loss,num_examples=0.,0
    with torch.no_grad():
        for features,targets in data_loader:
            features=features.to(dev)
            targets=targets.to(dev).long()
            logits=model(features)
            loss=tnnf.cross_entropy(logits,targets,reduction='sum')
            num_examples+=targets.size(0)
            curr_loss+=loss
        return curr_loss/num_examples

# %%
@register_line_magic
def train_run(epochs):
    epochs=int(epochs)
    st1='epoch: %03d/%03d || batch: %03d/%03d || cost: %.4f'
    for epoch in range(epochs):
        tmodel.train()
        for batch_ids,(features,targets) \
        in enumerate(dataloaders['train']):
            features=features.to(dev)
            targets=targets.to(dev).long()
            logits=tmodel(features)
            cost=tnnf.cross_entropy(logits,targets)
            optimizer.zero_grad(); cost.backward()
            optimizer.step()
            if not batch_ids%20:
                print(st1%(epoch+1,epochs,batch_ids,
                      len(dataloaders['train']),cost))
        tmodel.eval()
        with torch.set_grad_enabled(False):
            print('epoch: %03d/%03d'%(epoch+1,epochs))
            print('valid acc/loss: %.2f%%/%.2f'%\
                  (model_acc(tmodel,dataloaders['valid']),
                   epoch_loss(tmodel,dataloaders['valid'])))
tmodel.classifier[6]=tnn.Sequential(
    tnn.Linear(4096,256),tnn.ReLU(),
    tnn.Dropout(.5),tnn.Linear(256,num_classes))
tmodel=tmodel.to(dev)
optimizer=torch.optim.Adam(tmodel.parameters())
# %train_run 10
# Out:
# epoch: 001/010 || batch: 000/077 || cost: 2.7702
# epoch: 001/010 || batch: 020/077 || cost: 1.9134
# epoch: 001/010 || batch: 040/077 || cost: 1.9446
# epoch: 001/010 || batch: 060/077 || cost: 2.0488
# epoch: 001/010
# valid acc/loss: 62.50%/1.22
# epoch: 002/010 || batch: 000/077 || cost: 1.7671
# epoch: 002/010 || batch: 020/077 || cost: 0.9500
# epoch: 002/010 || batch: 040/077 || cost: 1.3303
# epoch: 002/010 || batch: 060/077 || cost: 1.6988
# epoch: 002/010
# valid acc/loss: 72.22%/0.99
# epoch: 003/010 || batch: 000/077 || cost: 1.1586
# epoch: 003/010 || batch: 020/077 || cost: 0.4713
# epoch: 003/010 || batch: 040/077 || cost: 1.0083
# epoch: 003/010 || batch: 060/077 || cost: 1.2732
# epoch: 003/010
# valid acc/loss: 62.50%/1.02
# epoch: 004/010 || batch: 000/077 || cost: 1.0306
# epoch: 004/010 || batch: 020/077 || cost: 0.7402
# epoch: 004/010 || batch: 040/077 || cost: 0.6190
# epoch: 004/010 || batch: 060/077 || cost: 1.1501
# epoch: 004/010
# valid acc/loss: 72.22%/0.77
# epoch: 005/010 || batch: 000/077 || cost: 0.7347
# epoch: 005/010 || batch: 020/077 || cost: 0.8449
# epoch: 005/010 || batch: 040/077 || cost: 1.1680
# epoch: 005/010 || batch: 060/077 || cost: 0.5661
# epoch: 005/010
# valid acc/loss: 75.00%/0.78
# epoch: 006/010 || batch: 000/077 || cost: 0.3648
# epoch: 006/010 || batch: 020/077 || cost: 1.0413
# epoch: 006/010 || batch: 040/077 || cost: 0.3031
# epoch: 006/010 || batch: 060/077 || cost: 1.3024
# epoch: 006/010
# valid acc/loss: 69.44%/0.80
# epoch: 007/010 || batch: 000/077 || cost: 0.1610
# epoch: 007/010 || batch: 020/077 || cost: 0.5795
# epoch: 007/010 || batch: 040/077 || cost: 0.4931
# epoch: 007/010 || batch: 060/077 || cost: 0.7917
# epoch: 007/010
# valid acc/loss: 72.22%/0.73
# epoch: 008/010 || batch: 000/077 || cost: 0.4060
# epoch: 008/010 || batch: 020/077 || cost: 1.0580
# epoch: 008/010 || batch: 040/077 || cost: 0.7901
# epoch: 008/010 || batch: 060/077 || cost: 1.0574
# epoch: 008/010
# valid acc/loss: 72.22%/0.79
# epoch: 009/010 || batch: 000/077 || cost: 0.7631
# epoch: 009/010 || batch: 020/077 || cost: 0.0940
# epoch: 009/010 || batch: 040/077 || cost: 1.0350
# epoch: 009/010 || batch: 060/077 || cost: 0.3887
# epoch: 009/010
# valid acc/loss: 80.56%/0.69
# epoch: 010/010 || batch: 000/077 || cost: 0.2716
# epoch: 010/010 || batch: 020/077 || cost: 0.3397
# epoch: 010/010 || batch: 040/077 || cost: 0.7863
# epoch: 010/010 || batch: 060/077 || cost: 0.5302
# epoch: 010/010
# valid acc/loss: 81.94%/0.66

# %%
tmodel.eval()
with torch.set_grad_enabled(False):
    print('test acc: %.2f%%'%model_acc(tmodel,dataloaders['test']))
# Out:
# test acc: 70.83%
